# %% [markdown]
# **Download Dataset** Installing dataset from kaggle

# %% [markdown]
# **Content**
# This is a public synthetic PCB dataset containing 1386 images with 6 kinds of defetcs (missing hole, mouse bite, open circuit, short, spur, spurious copper) for the use of detection, classification and registration tasks.

# %%
# %pip install ultralytics  # install
from ultralytics import YOLO, checks, hub
checks()  # checks
# Out:
# Ultralytics YOLOv8.0.150 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.4/78.2 GB disk)

# %%
hub.login('API_Key given by ultralytics')

model = YOLO('Link of model yolov5su given by ultralytics')
model.train()
# Out:
# Ultralytics HUB: Authenticated ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/7K1LH8wbwKVTyt1s9lNS 🚀
# ...
# 100%|██████████| 5.27M/5.27M [00:00<00:00, 28.9MB/s]
# Ultralytics YOLOv8.0.150 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
